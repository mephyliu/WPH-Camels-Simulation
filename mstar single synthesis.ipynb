# %% [markdown]
# The notebook uses pyWPH version 1.0

# %%
! pip install pywph==1.0
# Out:
# Collecting pywph==1.0
#   Downloading pywph-1.0-py3-none-any.whl (22 kB)
# WARNING: The candidate selected for download or install is a yanked version: 'pywph' candidate (version 1.0 at https://files.pythonhosted.org/packages/53/79/19ab051df789ff0e616b4283b174db5fff8bfd09a3d0b993ab47794a6ad8/pywph-1.0-py3-none-any.whl (from https://pypi.org/simple/pywph/) (requires-python:>=3.8))
# Reason for being yanked: Wrong requirements.
# Installing collected packages: pywph
# Successfully installed pywph-1.0

# %%
import numpy as np
import matplotlib.pyplot as plt
import pywph as pw
import torch
from torch import nn
from torch.nn import functional as F
from torch import optim
import time
import scipy.optimize as opt

# %%
# importing files from google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#nbody = np.load('drive/MyDrive/camels data/Maps_Mtot_Nbody_SIMBA_LH_z=0.00.npy')
mstar = np.load('drive/MyDrive/camels data/Maps_Mstar_SIMBA_LH_z=0.00.npy')

# %%
###
mstar_data = mstar[0]
for i in range(256):
  for j in range(256):
    if mstar_data[i,j] > 0:
      mstar_data[i,j] = np.log(mstar_data[i,j])
###


data = mstar_data
print(data.shape)

plt.title('mstar')
plt.imshow(data)
plt.colorbar()
# Out:
# (256, 256)

# %%
M = 256
N = 256
J = 7
L = 4
dn =0

wph_op = pw.WPHOp(M, N, J, L=L, dn=dn) # operator
coeff = wph_op(data) # get coefficients

# %%
# run on a GPU device
if torch.cuda.is_available():
    wph_op.to(0)

# %%
wph = wph_op(data, ret_wph_obj=True) # WPH object
print(wph)
# easier to get coefficients
# Out:
# <pywph.wph.WPH object at 0x7fc96250ee30>

# %%
# obtain coefficients and their corresponding indices
s11, s11_in = wph.get_coeffs("S11")
s00, s00_in = wph.get_coeffs("S00")
s01, s01_in = wph.get_coeffs("S01")
c01, c01_in = wph.get_coeffs("C01")
cphase,cphase_in = wph.get_coeffs("Cphase")

# %%
# s coefficients
fig, axs = plt.subplots(1, 3, figsize=(12, 2))

axs[0].plot(s11)
axs[1].plot(s00)
axs[2].plot(s01)

axs[0].set_title('S11')
axs[1].set_title('S00')
axs[2].set_title('S01')
axs[0].grid()
axs[1].grid()
axs[2].grid()

fig.tight_layout()
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
# c coefficients
fig, axs = plt.subplots(1, 2, figsize=(12, 2))
axs[0].plot(c01)
axs[1].plot(cphase)

axs[0].set_title('C01')
axs[1].set_title('Cphase')
axs[0].grid()
axs[1].grid()

fig.tight_layout()
fig.show()

# %%
# generate a noise image as an initial guess
guess = np.random.normal(data.mean(), data.std(), data.shape)

coeff = wph_op(data,norm='auto') # normalise data coefficients
print(coeff.shape)
print(guess.shape)
# Out:
# torch.Size([520])
# (256, 256)

# %%
# optimizer

count = 0

def objective(y):
    global count
    print(f"Evaluation: {count}")
    start_time = time.time()
    loss_tot = torch.zeros(1)

    Y = y.reshape((M, N)) # reshape y

    # calculate loss
    Y, chunks = wph_op.preconfigure(Y, requires_grad=True)
    for i in range(chunks):
        y_coeffs_chunk, indices = wph_op(Y, i, norm='auto', ret_indices=True) # get coefficients and indice
        loss = torch.sum(torch.abs(y_coeffs_chunk - coeff[indices])** 2) # compute residual
        loss.backward(retain_graph=True)
        loss_tot += loss.detach().cpu()
        del y_coeffs_chunk, indices, loss

    y_final = Y.grad.cpu().numpy().astype(y.dtype) # reshape gradient
    print(f"Loss: {loss_tot.item()} (computed in {(time.time() - start_time):.2f}s)")
    count += 1
    return loss_tot.item(), y_final.ravel()

# %%
objective(guess)
# Out:
# Evaluation: 0
# Loss: 95.442626953125 (computed in 0.42s)
# /usr/local/lib/python3.10/dist-packages/pywph/wph_operator.py:774: UserWarning: Casting complex values to real discards the imaginary part (Triggered internally at ../aten/src/ATen/native/Copy.cpp:276.)
#   xpsi1_k1 -= mean1.to(xpsi1_k1.dtype) # Consistent dtype needed
# (95.442626953125,
#  array([0.06335194, 0.05794196, 0.05946825, ..., 0.06252466, 0.06192191,
#         0.06024295]))

# %%
# run optimizer
# max number of iterations: 80
result = opt.minimize(objective, guess.ravel(), method='L-BFGS-B', jac=True, tol=None, options={"maxiter": 150, "gtol": 1e-14, "ftol": 1e-14, "maxcor": 20})
final_loss, final_guess, niter, msg = result['fun'], result['x'], result['nit'], result['message']
final_guess = final_guess.reshape(guess.shape)
print(f"Synthesis ended in {niter} iterations with optimizer message: {msg}")
# Out:
# Evaluation: 1
# Loss: 95.442626953125 (computed in 0.17s)
# Evaluation: 2
# Loss: 87.5973129272461 (computed in 0.17s)
# Evaluation: 3
# Loss: 84.85765075683594 (computed in 0.17s)
# Evaluation: 4
# Loss: 82.58586120605469 (computed in 0.17s)
# Evaluation: 5
# Loss: 969257.875 (computed in 0.17s)
# Evaluation: 6
# Loss: 102.51538848876953 (computed in 0.17s)
# Evaluation: 7
# Loss: 77.54227447509766 (computed in 0.17s)
# Evaluation: 8
# Loss: 74.60033416748047 (computed in 0.17s)
# Evaluation: 9
# Loss: 70.68968200683594 (computed in 0.17s)
# Evaluation: 10
# Loss: 27052.62109375 (computed in 0.17s)
# Evaluation: 11
# Loss: 60.93714141845703 (computed in 0.17s)
# Evaluation: 12
# Loss: 61.466392517089844 (computed in 0.19s)
# Evaluation: 13
# Loss: 56.542510986328125 (computed in 0.17s)
# Evaluation: 14
# Loss: 51.94599151611328 (computed in 0.18s)
# Evaluation: 15
# Loss: 43.748046875 (computed in 0.18s)
# Evaluation: 16
# Loss: 39.932518005371094 (computed in 0.18s)
# Evaluation: 17
# Loss: 36.581092834472656 (computed in 0.18s)
# Evaluation: 18
# Loss: 30.169452667236328 (computed in 0.18s)
# Evaluation: 19
# Loss: 0.17640069127082825 (computed in 0.17s)
# Evaluation: 139
# Loss: 0.17544208467006683 (computed in 0.17s)
# Evaluation: 140
# Loss: 0.1741345077753067 (computed in 0.17s)
# Evaluation: 141
# Loss: 0.17217743396759033 (computed in 0.17s)
# Evaluation: 142
# Loss: 0.17528440058231354 (computed in 0.17s)
# Evaluation: 143
# Loss: 0.17126786708831787 (computed in 0.17s)
# Evaluation: 144
# Loss: 0.170268714427948 (computed in 0.17s)
# Evaluation: 145
# Loss: 0.16864264011383057 (computed in 0.17s)
# Evaluation: 146
# Loss: 0.16745316982269287 (computed in 0.18s)
# Evaluation: 147
# Loss: 0.16643214225769043 (computed in 0.20s)
# Evaluation: 148
# Loss: 0.16526572406291962 (computed in 0.20s)
# Evaluation: 149
# Loss: 0.1640075445175171 (computed in 0.17s)
# Evaluation: 150
# Loss: 0.16301709413528442 (computed in 0.18s)
# Evaluation: 151
# Loss: 0.1619667261838913 (computed in 0.18s)
# Evaluation: 152
# Loss: 0.16174732148647308 (computed in 0.17s)
# Evaluation: 153
# Loss: 0.16008812189102173 (computed in 0.18s)
# Evaluation: 154
# Loss: 0.15940865874290466 (computed in 0.18s)
# Evaluation: 155
# Loss: 0.15802213549613953 (computed in 0.18s)
# Evaluation: 156
# Loss: 0.15653997659683228 (computed in 0.17s)
# Evaluation: 157
# Loss: 0.1551256626844406 (computed in 0.17s)
# Evaluation: 158
# Loss: 0.1537562757730484 (computed in 0.17s)
# Evaluation: 159
# Loss: 0.1525159776210785 (computed in 0.17s)
# Evaluation: 160
# Loss: 0.1529644876718521 (computed in 0.17s)
# Evaluation: 161
# Loss: 0.1522236466407776 (computed in 0.18s)
# Evaluation: 162
# Loss: 0.15169157087802887 (computed in 0.18s)
# Evaluation: 163
# Loss: 0.1508939564228058 (computed in 0.17s)
# Evaluation: 164
# Loss: 0.15000763535499573 (computed in 0.17s)
# Evaluation: 165
# Loss: 0.14858587086200714 (computed in 0.17s)
# Synthesis ended in 150 iterations with optimizer message: STOP: TOTAL NO. of ITERATIONS REACHED LIMIT

# %%
#
plt.imshow(final_guess)
plt.colorbar()

# %%
fig, axs = plt.subplots(1, 3, figsize=(8, 8))

axs[0].imshow(guess)
axs[1].imshow(final_guess)
axs[2].imshow(data)

axs[0].set_title('random')
axs[1].set_title('syntehsis')
axs[2].set_title('mstar')


fig.tight_layout()
fig.show()

# %%
# compare s11 coefficients

wph1 = wph_op(final_guess, ret_wph_obj=True) # WPH object
s11_guess, s11_in_guess = wph.get_coeffs("S11")

fig, axs = plt.subplots(1, 2, figsize=(12, 2))
axs[0].plot(s11)
axs[1].plot(s11_guess)
axs[0].set_title('mstar')
axs[1].set_title('synthesis')
axs[0].grid()
axs[1].grid()

fig.tight_layout()
fig.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/matplotlib/cbook/__init__.py:1335: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)
